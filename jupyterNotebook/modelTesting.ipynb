# %%
# connecting to google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#changing to current working directory
import os

project_folder = "drive//MyDrive//creditCardDefaultClassification"
os.chdir(project_folder)

os.getcwd()
# Out:
# '/content/drive/MyDrive/creditCardDefaultClassification'

# %%
#Installing catboost and xgboost
# !pip install catboost
# !pip install xgboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.5 MB/s eta 0:00:00
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %%
#importing libraries
import pickle

# %%
model_path = ".//dataFiles//stacking_final_model.pkl"

with open(model_path, "rb") as file_pointer:
    model = pickle.load(file_pointer)

# %%
import numpy as  np
import pandas as pd

dict_test_data = {
    "LIMIT_BAL" : 0.137255,
    "PAY_SEPT" : 2,
    "BILL_AMT_MAY" : 0.493133,
    "BILL_AMT_APRIL" : 0.481400,
    "PAY_AMT_SEPT" : 0.000999,
    "PAY_AMT_JULY" : 0.000000,
    "PAY_AMT_JUNE" : 0.107784,
    "PAY_AMT_MAY" : 0.154845,
    "PAY_AMT_APRIL" : 0.203932
}

data_input = pd.DataFrame(dict_test_data, index = [0])

data_input
# Out:
#    LIMIT_BAL  PAY_SEPT  BILL_AMT_MAY  BILL_AMT_APRIL  PAY_AMT_SEPT  \
# 0   0.137255         2      0.493133          0.4814      0.000999
#
#    PAY_AMT_JULY  PAY_AMT_JUNE  PAY_AMT_MAY  PAY_AMT_APRIL
# 0           0.0      0.107784     0.154845       0.203932

# %%
model.predict(data_input)
# Out:
# array([1])
